# %% [markdown]
# <style  type="text/css">
# cool {
#   width: 100px;
#   height: 100px;
#   background-color: red;
#   position: relative;
#   -webkit-animation-name: example; /* Safari 4.0 - 8.0 */
#   -webkit-animation-duration: 4s; /* Safari 4.0 - 8.0 */
#   -webkit-animation-iteration-count: infinite; /* Safari 4.0 - 8.0 */
#   animation-name: example;
#   animation-duration: 4s;
#   animation-iteration-count: infinite;
# }
#
# /* Safari 4.0 - 8.0 */
# @-webkit-keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
# /* Standard syntax */
# @keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
# </style>
#
# <b><center>
# <span style="font-size: 24pt; line-height: 1.2">
# COMS W4111: Introduction to Databases
# </span>
# </center></b>
# </span><br>
# <p>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2">
# Homework 1A: Programming Track Environment
# </span>
# </center></i>

# %% [markdown]
# # Introduction
#
# Homework 1A tests environment setup. The total point value for HW1 is 10 points. Environment setup is necessary to complete HW1. Completing HW1A demonstrates that the environment setup is complete and correct. Details:
# 1. HW1A is due on 01-Feb-2020 at 11:59 PM. __You may not use grace days.__<br><br>
# 2. HW1A is worth 2.5 points out of the total 10 points for HW1.<br><br>
# 3. You will need a working setup to complete HW1. If you do not submit HW1A, your maximum grade on the full HW1 is 7.5 points.

# %% [markdown]
# # Anaconda
#
#
# - You must install Anaconda 3. There are [on-line instructions.](https://www.anaconda.com/distribution/)

# %% [markdown]
# - Test correct version of Python by running the code below.

# %%
import sys

print("Python version information:", sys.version_info, "\n")
if sys.version_info.major != 3 or \
    ((sys.version_info.major == 3) and (sys.version_info.minor < 5)):
    print("You have an invalid version of Python.")
else:
    print("Your Python version is OK.")
# Out:
# Python version information: sys.version_info(major=3, minor=7, micro=4, releaselevel='final', serial=0)
#
# Your Python version is OK.

# %% [markdown]
# - Test the Python path

# %%
python_found = False
anaconda_found = False

for p in sys.path:
    print(p)
    if "anaconda3" in p:
        print("Found anaconda3")
        anaconda_found = True
    if "python" in p:
        print("Found some kind of Python.")
        if not anaconda_found:
            print("Found some type of Python other than Anaconda.")
            print("Test fails")
        else:
            print("OK. Path is good.")
            python_found = True
        break
    
if python_found and anaconda_found:
    print("\nPassed all path tests.")
else:
    print("\nFailed path tests.")
# Out:
# /Users/donaldferguson/OneDrive - ANSYS, Inc/Columbia/IntroToDatabases/HW_Assignments/HW1/Non_Programming
# /Users/donaldferguson/opt/anaconda3/lib/python37.zip
# Found anaconda3
# Found some kind of Python.
# OK. Path is good.
#
# Passed all path tests.

# %% [markdown]
# - Test Conda/Anaconda Version

# %%
import conda

# %%
conda_version_info =  conda.sys.version_info
print("Your conda version info is\n", conda_version_info)

print("Conda version information:", conda_version_info, "\n")
if conda_version_info.major != 3 or \
    ((conda_version_info.major == 3) and (conda_version_info.minor < 6)):
    print("You have an invalid version of Conda.")
else:
    print("Your Conda version is OK.")
# Out:
# Your conda version info is
#  sys.version_info(major=3, minor=7, micro=4, releaselevel='final', serial=0)
# Conda version information: sys.version_info(major=3, minor=7, micro=4, releaselevel='final', serial=0)
#
# Your Conda version is OK.

# %% [markdown]
# - Test Pandas

# %%
import pandas

p_version = pandas.__version__
p_nums = p_version.split(".")

print("Your pandas version is ", p_version)
if p_nums[1] != '25':
    print("Your version is invalid.")
else:
    print("Your version is OK.")
# Out:
# Your pandas version is  0.25.1
# Your version is OK.

# %% [markdown]
# - The following fragment promps your for input. Please enter y or n.

# %%
print("Professor Ferguson gave us code that accesses a module's property of the form __X__")
ans = input("Answer y or n:")

if ans == 'y' or ans == 'Y':
    print("You failed the test. Prof. Ferguson is to good a programmer to ever do that.")
    print("Reformatting harddrive as punishment.")
elif ans == 'n' or ans == 'N':
    print("You passed the test.")
else:
    print("Really. Answering y or n was too tricky?")
# Out:
# Professor Ferguson gave us code that accesses a module's property of the form __X__
# Answer y or n:y
# You failed the test. Prof. Ferguson is to good a programmer to ever do that.
# Reformatting harddrive as punishment.

# %% [markdown]
# # ipython-sql
#
# - Run the following code cell.

# %%
# !pip install ipython-sql

# %% [markdown]
# - If you got errors, please follow the [instructions in the ipython-sql site](https://github.com/catherinedevlin/ipython-sql) to install the magic.
#
#
# - __NOTE:__ Running the cell above may produce multiple notifications about installing requirements or requirement already satisfied. That is normal.
#
#
#
# - Once you get the install to work without errors, run the following cell.

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# - If you did not get an error response, your test passed.
#
#
# - If you run the cell twice, your answer should be:
#
# ```
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# ```

# %% [markdown]
# - If you got the expected answer, your test passed.

# %% [markdown]
# # MySQL
#
# ## Setup
#
# - Install the most recent versions of MySQL and MySQL Workbench. The download links are:
#     - MySQL Community Server: https://dev.mysql.com/downloads/mysql/
#     - MySQL Workbench: https://dev.mysql.com/downloads/workbench/
#
#
#
# - Follow the on-line installation instructions.
#
#
# - When installing MySQL Community Server,
#     - Choose the old/legacy password security option.
#     - Choose ```root``` for the administrative user.
#     - If MySQL generates a root password, make sure you write it down in a place where you will not loose it. If you set the password, make sure your write it down.
#
#
# ## Tests
#
# - Start MySQL Workbench.
#     - There should be an already defined connection button. Connect to the DB server.
#     - If there is not a connection, click to create one. Accept the default options but use the password you set.
#         - The hosts should be 127.0.0.1
#         - Port: 3306
#         - User: root
#
#
# - Your window should look something like (note: your color scheme will be different):
#
# <hr style="height:2px;">
# <img src="./mysqlworkbench.png">
# <hr style="height:2px;">

# %% [markdown]
# - Right click in the left panel and choose ```Create Schema```
#     - The schema name should be ```W4111```
#     - Character set should be ```utf8mb4```
#     - Collection should be ```utf8mb4_bin```
#     - Create the schema (click Apply)
#
#
# - You should see the new schema in the left pane.
#
#
# - Right on the new schema and choose ```Set as Default Schema```
#
#
# - Right click on ```Tables``` and choose ```Create Table```
#
#
# - The table creation tool will appear.  Use the tool to create a table. Your screen should look like below before you click apply.
#
# <hr style="height:2px;">
# <img src="./wb_create_table.png">
# <hr style="height:2px;">

# %% [markdown]
# - Run the following cell, but replace the password with your root password to MySQL.

# %%
# %load_ext sql
# %sql mysql+pymysql://dbuser:dbuserdbuser@localhost/w4111
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: dbuser@w4111'

# %% [markdown]
# - Run the following cell.

# %%
# %sql select * from countries;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/w4111
# 0 rows affected.
# []

# %% [markdown]
# - Run the following cell.

# %% [markdown]
# - Run the following cell.

# %%
import pandas as pd

url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
countries=pd.read_csv(url)
countries
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# - The result will be formatted but should contain data like ...
#
# ```
#     Country	Region
# 0	Algeria	AFRICA
# 1	Angola	AFRICA
# 2	Benin	AFRICA
# 3	Botswana	AFRICA
# 4	Burkina	AFRICA
# ...	...	...
# 189	Paraguay	SOUTH AMERICA
# 190	Peru	SOUTH AMERICA
# 191	Suriname	SOUTH AMERICA
# 192	Uruguay	SOUTH AMERICA
# 193	Venezuela	SOUTH AMERICA
# ```

# %% [markdown]
# - Run the following cells

# %%
countries.rename(columns={"Country": "name", "Region": "region"}, inplace=True)
countries
# Out:
#           name         region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# - Create a connection. Replace the userid with ```root``` and set the password to the password you used.

# %%
import pymysql
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://dbuser:dbuserdbuser@localhost/w4111')

# %% [markdown]
# - Run the following cell.

# %%
countries.to_sql(name='countries', con=engine, if_exists='append', index='id');

# %% [markdown]
# - The statement worked if you did not get an error.
#
#
# - Run the following cell.

# %%
# %sql select * from countries;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/w4111
# 194 rows affected.
# [(0, 'Algeria', 'AFRICA'),
#  (1, 'Angola', 'AFRICA'),
#  (2, 'Benin', 'AFRICA'),
#  (3, 'Botswana', 'AFRICA'),
#  (4, 'Burkina', 'AFRICA'),
#  (5, 'Burundi', 'AFRICA'),
#  (6, 'Cameroon', 'AFRICA'),
#  (7, 'Cape Verde', 'AFRICA'),
#  (8, 'Central African Republic', 'AFRICA'),
#  (9, 'Chad', 'AFRICA'),
#  (10, 'Comoros', 'AFRICA'),
#  (11, 'Congo', 'AFRICA'),
#  (12, 'Congo, Democratic Republic of', 'AFRICA'),
#  (13, 'Djibouti', 'AFRICA'),
#  (14, 'Egypt', 'AFRICA'),
#  (15, 'Equatorial Guinea', 'AFRICA'),
#  (16, 'Eritrea', 'AFRICA'),
#  (17, 'Ethiopia', 'AFRICA'),
#  (18, 'Gabon', 'AFRICA'),
#  (19, 'Gambia', 'AFRICA'),
#  (20, 'Ghana', 'AFRICA'),
#  (21, 'Guinea', 'AFRICA'),
#  (22, 'Guinea-Bissau', 'AFRICA'),
#  (23, 'Ivory Coast', 'AFRICA'),
#  (24, 'Kenya', 'AFRICA'),
#  (25, 'Lesotho', 'AFRICA'),
#  (26, 'Liberia', 'AFRICA'),
#  (27, 'Libya', 'AFRICA'),
#  (28, 'Madagascar', 'AFRICA'),
# ...

# %% [markdown]
# - Go into MySQL Workbench. Open a query tab of one does not exist. Run the query<br><br>
# ```select * from countries;```
#
#
# - Your window should look something like ...
#
# <hr style="height:2px;">
# <img src="./wb_query.png">
# <hr style="height:2px;">

# %% [markdown]
# # Git
#
# - MacOS comes with ```git``` installed.
#
#
# - If you do not have ```git``` on Windows, install it. There are [on-line instructions](https://git-scm.com/download/win).
#
#
# - Open a ```git``` command window after installation.
#
#
# - Create a directory IntroToDBHW. I suggest on your desktop.
#
#
# - CD to the directory. Run the command: https://github.com/donald-f-ferguson/W4111_HW1_P.git
#
#
# - This should clone the HW1 repository into the directory.

# %% [markdown]
# # PyCharm
#
# - Download and install the professional version of PyCharm. You can get a free license if you use your Columbia email ID.
#
# - The link is: https://www.jetbrains.com/student/
#
#
# - When you receive the email with the installation link, install PyCharm.
#
#
# - After installation, start PyCharm. Open the directory you created above.
#
#
# - Using the menu option for preference, set the Project Interpreter for your project to your Anaconda3 installation. The path on my System is ```~/opt/anaconda3/bin/python3.7``` Your path may be different.
#
#
# - PyCharm will setup your environment.
#
#
# - Open the file ```mysql_t1.py```
#
#
# - Write click on the file in the project explorer. Choose to run the program. Your answer should be something like ...
#
# <hr style="height:2px;">
# <img src="./pycharm_result.png">
# <hr style="height:2px;">

# %% [markdown]
# # Flask
#
# - Run the Python file ```application.py```
#
#
# - Your window should look something like.
#
# <hr style="height:2px;">
# <img src="./py_flask.png">
# <hr style="height:2px;">

# %% [markdown]
# # Postman
#
# - Install Postman. Instructions are at: https://www.getpostman.com/downloads/
#
#
# - After installation, start Postman.
#
#
# - Enter the URL ```127.0.0.1:5000``` where it says ```Enter URL``` next to ```GET``` Your window should look something like.
#
#
# <hr style="height:2px;">
# <img src="./postman.png">
# <hr style="height:2px;">
